# %% [markdown]
# ### Setup

# %%
import datetime

import os
pwd = os.path.abspath('.')
os.chdir(os.path.join(pwd, '../src/'))

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Import

# %%
from markets_insights.datareader.data_reader import DataReader, DateRangeSourceDataReader, ReaderDateCriteria, NseIndicesReader, BhavCopyReader, \
   ForDateCriteria, DateRangeCriteria, Status, ReaderDataAvailibilityStatus, ReaderDataAvailibility, NseIndicesNewReader, NseDerivatiesReader, MemoryCachedDataReader
import pandas as pd
from datetime import date

# %% [markdown]
# ### Readers

# %%
reader = NseIndicesReader()
#reader.read( DateRangeCriteria(from_date=date(2023, 1, 1), to_date=date(2023, 1, 31)) )
reader.read( DateRangeCriteria(from_date=date(1991, 1, 1), to_date=date(1991, 1, 31)) )
# Out:
#          Date    Open    High     Low   Close Identifier  PreviousClose  \
# 88 1991-01-02  318.95  318.95  318.95  318.95   NIFTY 50         314.01
# 89 1991-01-03  314.01  314.01  314.01  314.01   NIFTY 50         318.12
# 90 1991-01-07  318.12  318.12  318.12  318.12   NIFTY 50         321.49
# 91 1991-01-09  321.49  321.49  321.49  321.49   NIFTY 50         326.37
# 92 1991-01-11  326.37  326.37  326.37  326.37   NIFTY 50         323.42
# 93 1991-01-14  323.42  323.42  323.42  323.42   NIFTY 50         319.49
# 94 1991-01-23  319.49  319.49  319.49  319.49   NIFTY 50         312.07
# 95 1991-01-24  312.07  312.07  312.07  312.07   NIFTY 50         306.22
# 96 1991-01-25  306.22  306.22  306.22  306.22   NIFTY 50         314.36
# 97 1991-01-31  314.36  314.36  314.36  314.36   NIFTY 50            NaN
#
#     Volume  Turnover
# 88     0.0       0.0
# 89     0.0       0.0
# 90     0.0       0.0
# 91     0.0       0.0
# 92     0.0       0.0
# 93     0.0       0.0
# 94     0.0       0.0
# 95     0.0       0.0
# 96     0.0       0.0
# 97     0.0       0.0

# %%
reader = MemoryCachedDataReader(BhavCopyReader())
criteria = DateRangeCriteria(from_date=date(2024, 1, 1), to_date=date(2024, 1, 31))
reader.read(criteria)
# Out:
#       Identifier SERIES      Open      High       Low     Close     LAST  \
# 0      20MICRONS     EQ    177.20    182.95    176.00    176.50    176.5
# 1         360ONE     EQ    709.85    714.40    693.00    702.85    693.7
# 2      3IINFOLTD     EQ     49.20     52.90     49.20     52.50     52.6
# 3        3MINDIA     EQ  37000.00  37500.00  36405.00  36659.95  36570.0
# 4         3PLAND     EQ     27.00     28.85     26.75     27.15     27.2
# ...          ...    ...       ...       ...       ...       ...      ...
# 37842       ZOTA     EQ    490.05    520.00    490.05    507.15    501.2
# 37843      ZUARI     EQ    232.00    247.40    230.00    244.80    245.2
# 37844   ZUARIIND     EQ    270.70    294.00    264.95    290.75    292.0
# 37845  ZYDUSLIFE     EQ    755.90    766.00    745.00    760.80    761.0
# 37846  ZYDUSWELL     EQ   1601.50   1634.35   1601.50   1614.95   1615.0
#
#        PreviousClose      Volume      Turnover    TIMESTAMP  TOTALTRADES  \
# 0             176.20    117885.0  2.100939e+07  01-JAN-2024         7671
# 1             709.85    175009.0  1.240067e+08  01-JAN-2024        29383
# 2              48.95  10164866.0  5.252125e+08  01-JAN-2024        31587
# 3           37309.15     10350.0  3.833053e+08  01-JAN-2024         6005
# 4              26.90     14356.0  3.911097e+05  01-JAN-2024          495
# ...              ...         ...           ...          ...          ...
# 37842         496.95     85218.0  4.352437e+07  31-JAN-2024         3923
# 37843         232.00    761637.0  1.850582e+08  31-JAN-2024        18997
# 37844         269.75    324067.0  9.264913e+07  31-JAN-2024         5274
# 37845         755.90    993266.0  7.547988e+08  31-JAN-2024        42313
# 37846        1601.50     22773.0  3.679697e+07  31-JAN-2024         4543
#
#                ISIN  Unnamed: 13       Date
# 0      INE144J01027          NaN 2024-01-01
# 1      INE466L01038          NaN 2024-01-01
# 2      INE748C01038          NaN 2024-01-01
# 3      INE470A01017          NaN 2024-01-01
# 4      INE105C01023          NaN 2024-01-01
# ...             ...          ...        ...
# 37842  INE358U01012          NaN 2024-01-31
# 37843  INE840M01016          NaN 2024-01-31
# 37844  INE217A01012          NaN 2024-01-31
# 37845  INE010B01027          NaN 2024-01-31
# 37846  INE768C01010          NaN 2024-01-31
#
# [37847 rows x 15 columns]

# %%
reader.options.col_prefix
# Out:
# 'Cash-'

# %%
from functools import partial

from markets_insights.core.core import IdentifierFilter


BhavCopyCachedReader = partial(MemoryCachedDataReader, BhavCopyReader())
reader = BhavCopyCachedReader().set_filter(IdentifierFilter("RELIANCE"))

# %%
reader.set_filter(None)

# %%
reader.read(criteria)
# Out:
#       Identifier SERIES      Open      High       Low     Close     LAST  \
# 0      20MICRONS     EQ    177.20    182.95    176.00    176.50    176.5
# 1         360ONE     EQ    709.85    714.40    693.00    702.85    693.7
# 2      3IINFOLTD     EQ     49.20     52.90     49.20     52.50     52.6
# 3        3MINDIA     EQ  37000.00  37500.00  36405.00  36659.95  36570.0
# 4         3PLAND     EQ     27.00     28.85     26.75     27.15     27.2
# ...          ...    ...       ...       ...       ...       ...      ...
# 37842       ZOTA     EQ    490.05    520.00    490.05    507.15    501.2
# 37843      ZUARI     EQ    232.00    247.40    230.00    244.80    245.2
# 37844   ZUARIIND     EQ    270.70    294.00    264.95    290.75    292.0
# 37845  ZYDUSLIFE     EQ    755.90    766.00    745.00    760.80    761.0
# 37846  ZYDUSWELL     EQ   1601.50   1634.35   1601.50   1614.95   1615.0
#
#        PreviousClose      Volume      Turnover    TIMESTAMP  TOTALTRADES  \
# 0             176.20    117885.0  2.100939e+07  01-JAN-2024         7671
# 1             709.85    175009.0  1.240067e+08  01-JAN-2024        29383
# 2              48.95  10164866.0  5.252125e+08  01-JAN-2024        31587
# 3           37309.15     10350.0  3.833053e+08  01-JAN-2024         6005
# 4              26.90     14356.0  3.911097e+05  01-JAN-2024          495
# ...              ...         ...           ...          ...          ...
# 37842         496.95     85218.0  4.352437e+07  31-JAN-2024         3923
# 37843         232.00    761637.0  1.850582e+08  31-JAN-2024        18997
# 37844         269.75    324067.0  9.264913e+07  31-JAN-2024         5274
# 37845         755.90    993266.0  7.547988e+08  31-JAN-2024        42313
# 37846        1601.50     22773.0  3.679697e+07  31-JAN-2024         4543
#
#                ISIN  Unnamed: 13       Date
# 0      INE144J01027          NaN 2024-01-01
# 1      INE466L01038          NaN 2024-01-01
# 2      INE748C01038          NaN 2024-01-01
# 3      INE470A01017          NaN 2024-01-01
# 4      INE105C01023          NaN 2024-01-01
# ...             ...          ...        ...
# 37842  INE358U01012          NaN 2024-01-31
# 37843  INE840M01016          NaN 2024-01-31
# 37844  INE217A01012          NaN 2024-01-31
# 37845  INE010B01027          NaN 2024-01-31
# 37846  INE768C01010          NaN 2024-01-31
#
# [37847 rows x 15 columns]
