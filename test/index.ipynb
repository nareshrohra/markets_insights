# %%
import pandas
from pandas_datareader import data as pdr
import yfinance as yfin
import datetime as dt

# %%
yfin.pdr_override()

djia = pdr.get_data_yahoo('DJI', start='1986-01-01', end='2023-07-31')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
djia['CloseDiff'] = djia['Close'].diff(1)

# %%
djia['CloseDiffPerc'] = djia['CloseDiff'] / djia['Close'].shift(-1) * 100

# %%
djia['NoRecentCloseBelowX'] = djia['CloseDiffPerc'].transform(lambda x: x.rolling(44).min() > -1)
djia[djia['NoRecentCloseBelowX'] == True]
# Out:
#                     Open          High           Low         Close  \
# Date
# 1987-01-22   2145.669922   2145.669922   2145.669922   2145.669922
# 1991-10-21   3060.379883   3060.379883   3060.379883   3060.379883
# 1991-10-22   3039.800049   3039.800049   3039.800049   3039.800049
# 1991-10-23   3040.919922   3040.919922   3040.919922   3040.919922
# 1991-10-24   3016.320068   3016.320068   3016.320068   3016.320068
# ...                  ...           ...           ...           ...
# 2018-10-05  26632.800781  26676.199219  26301.800781  26447.099609
# 2018-10-08  26399.400391  26529.300781  26223.099609  26486.800781
# 2018-10-09  26469.199219  26539.900391  26324.199219  26430.599609
# 2021-05-07  34777.800781  34777.800781  34777.800781  34777.800781
# 2021-05-10  34742.800781  34742.800781  34742.800781  34742.800781
#
#                Adj Close     Volume   CloseDiff  CloseDiffPerc  \
# Date
# 1987-01-22   2145.669922          0   51.599854       2.455359
# ...
